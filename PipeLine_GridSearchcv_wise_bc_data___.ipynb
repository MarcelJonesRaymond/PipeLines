# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.model_selection import  GridSearchCV,train_test_split,StratifiedKFold,cross_val_score
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.svm import SVC,SVR
from sklearn import metrics
from sklearn.decomposition import PCA

# %%
data= pd.read_csv('wisc_bc_data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
data.tail()
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 564  911320502         B        13.17         18.22           84.28
# 565     898677         B        10.26         14.71           66.20
# 566     873885         M        15.28         22.41           98.92
# 567     911201         B        14.53         13.98           93.86
# 568    9012795         M        21.37         15.10          141.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 564      537.3          0.07466           0.05994         0.04859
# 565      321.6          0.09882           0.09159         0.03581
# 566      710.6          0.09057           0.10520         0.05375
# 567      644.2          0.10990           0.09242         0.06895
# 568     1386.0          0.10010           0.15150         0.19320
#
#      points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 564      0.02870  ...         14.90          23.89            95.10
# ...

# %%
data.sample(5)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 200   855133         M        14.99         25.20           95.54      698.8
# 297   849014         M        19.81         22.15          130.00     1260.0
# 176   857637         M        19.21         18.57          125.50     1152.0
# 137   871122         B        12.06         12.74           76.84      448.6
# 471  8712291         B        14.97         19.76           95.50      690.2
#
#      smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 200          0.09387           0.05131         0.02398      0.02899  ...
# 297          0.09831           0.10270         0.14790      0.09498  ...
# 176          0.10530           0.12670         0.13230      0.08994  ...
# 137          0.09311           0.05241         0.01972      0.01963  ...
# 471          0.08421           0.05352         0.01947      0.01939  ...
#
# ...

# %%
data.dtypes
# Out:
# id                     int64
# diagnosis             object
# radius_mean          float64
# texture_mean         float64
# perimeter_mean       float64
# area_mean            float64
# smoothness_mean      float64
# compactness_mean     float64
# concavity_mean       float64
# points_mean          float64
# symmetry_mean        float64
# dimension_mean       float64
# radius_se            float64
# texture_se           float64
# perimeter_se         float64
# area_se              float64
# smoothness_se        float64
# compactness_se       float64
# concavity_se         float64
# points_se            float64
# symmetry_se          float64
# dimension_se         float64
# radius_worst         float64
# texture_worst        float64
# perimeter_worst      float64
# area_worst           float64
# smoothness_worst     float64
# compactness_worst    float64
# concavity_worst      float64
# points_worst         float64
# symmetry_worst       float64
# dimension_worst      float64
# ...

# %%
label=LabelEncoder()
data['diagnosis']=label.fit_transform(data['diagnosis'])

# %%
x=data.drop('diagnosis',1)
y=data[['diagnosis']]

# %%
X_train,x_test,Y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
svm=SVC()
result=cross_val_score(svm,X_train,Y_train,cv=10)
# Out:
# E:\Anacondafiles\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Anacondafiles\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Anacondafiles\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# E:\Anacondafiles\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
result.mean()
# Out:
# 0.595576923076923

# %%
result.std()
# Out:
# 0.04141586252438857

# %%
kfold=StratifiedKFold(n_splits=10)
for train,test in kfold.split(x,y):
    X_train_sm,Y_train_sm=x.loc[train],y.loc[train]
    x_test_sm,y_test_sm=x.loc[test],y.loc[test]

# %%
import warnings
warnings.filterwarnings('ignore')
cv=StratifiedKFold(n_splits=10)
result=cross_val_score(svm,X_train_sm,Y_train_sm,cv=cv)
print('Model performance  with the avg accuracy of',result.mean(), '  and STD of ',result.std())
# Out:
# Model performance  with the avg accuracy of 0.6198340874811462   and STD of  0.01656449233760681

# %%
pipe=make_pipeline(StandardScaler(),PCA(2),SVC())

# %%
pipe.fit(X_train_sm,Y_train_sm)
yhat_pipe=pipe.predict(x_test_sm)
print(metrics.classification_report(y_test_sm,yhat_pipe))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        35
#            1       0.95      0.90      0.93        21
#
#     accuracy                           0.95        56
#    macro avg       0.95      0.94      0.94        56
# weighted avg       0.95      0.95      0.95        56

# %%
result=cross_val_score(pipe,X_train,Y_train,cv=10)
print('Model performance  with the avg accuracy of',result.mean(), '  and STD of ',result.std())
# Out:
# Model performance  with the avg accuracy of 0.9396794871794872   and STD of  0.04942257806792037

# %%
param_grid = {'pca__n_components':[14,15],'svc__C': [0.001, 0.01, 0.1, 1, 10, 100], 'svc__gamma': [0.001, 0.01, 0.1, 1, 10], 'svc__kernel':['rbf','poly']}

# %%
model=GridSearchCV(pipe,param_grid,cv=10)
model.fit(X_train_sm,Y_train_sm)
model.best_params_
# Out:
# {'pca__n_components': 15,
#  'svc__C': 10,
#  'svc__gamma': 0.01,
#  'svc__kernel': 'rbf'}

# %%
yhat_best=model.predict(x_test_sm)
print(metrics.classification_report(y_test_sm,yhat_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        35
#            1       1.00      1.00      1.00        21
#
#     accuracy                           1.00        56
#    macro avg       1.00      1.00      1.00        56
# weighted avg       1.00      1.00      1.00        56

# %%
print(metrics.confusion_matrix(y_test_sm,yhat_best))
# Out:
# [[35  0]
#  [ 0 21]]
